# %% [markdown]
# <a href="https://colab.research.google.com/github/Adib234/Leetcode/blob/master/DataCollection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install dnspython
! pip install pymongo[srv]
# initial imports and settings
import pandas as pd
import pymongo

from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# ...
#      |████████████████████████████████| 215kB 3.3MB/s
# ...
#      |████████████████████████████████| 194kB 3.4MB/s
# ...
#   Found existing installation: dnspython 2.0.0
#     Uninstalling dnspython-2.0.0:
#       Successfully uninstalled dnspython-2.0.0
# ...
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
# connecting to mongo database
#client = pymongo.MongoClient("mongodb://localhost:27017/") # replace with mongo link
client = pymongo.MongoClient("mongodb+srv://saarang:1234@userdb.fy9ao.mongodb.net/userdb?retryWrites=true") # replace with mongo link

db = client["userdb"] #change if the database name changes
col = db["matchingresponses"] #change if te collection name changes

# %%
# constants
base_path = F"/content/gdrive/My Drive"

data_source = "test_event" # update this one to change where data is stored
data_path = F"{base_path}/data/{data_source}"

# %%
# do data collection
x = col.find() #x is a cursor
all_data = []
for data in x:
  all_data.append(data)
#converting cursor to a list
list_x = list(x)
#converting list to dataframe
finished_pandas_object_with_data = pd.DataFrame(all_data)# , #columns=['id', 'confirmed', 'resetToken', 'tokenValid', 'name', 'email', 'password', 'date'])

finished_pandas_object_with_data.drop(columns=['q1', 'secondRound', 'email', 'date'])

# print(finished_pandas_object_with_data)
# Out:
#                          _id   q4   q5   q6   q7   q8  ... q57 q58 q59 q60 q61 __v
# 0   5f4acfc8de96ae38d4efb896  [a]  [a]  [a]  [b]  [a]  ...   b   a   a   b   b   0
# 1   5f522f5a3b3ab7da22524925  [b]  [b]  [b]  [c]  [b]  ...   b   a   a   b   b   0
# 2   5f5230963b3ab7da22524927  [a]  [a]  [a]  [b]  [a]  ...   b   a   a   b   b   0
# 3   5f5231473b3ab7da22524928  [b]  [a]  [b]  [c]  [b]  ...   b   a   a   b   b   0
# 4   5f52318e3b3ab7da22524929  [a]  [a]  [a]  [b]  [a]  ...   a   a   a   b   b   0
# 5   5f5232253b3ab7da2252492a  [a]  [a]  [b]  [b]  [c]  ...   a   a   a   b   b   0
# 6   5f52326a3b3ab7da2252492c  [a]  [a]  [b]  [b]  [c]  ...   a   a   a   b   b   0
# 7   5f5232b03b3ab7da2252492d  [b]  [b]  [b]  [b]  [c]  ...   a   a   a   b   b  10
# 8   5f5233063b3ab7da2252492f  [b]  [b]  [b]  [b]  [a]  ...   a   a   a   b   b  10
# 9   5f52337a3b3ab7da22524930  [a]  [a]  [a]  [a]  [b]  ...   a   a   a   b   b   1
# ...

# %%
# save data to google drive
finished_pandas_object_with_data.to_csv(data_path)
